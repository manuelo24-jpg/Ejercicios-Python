# %%
from ultralytics import YOLO
# 1. Cargar un modelo pre-entrenado (YOLOv8 nano es rápido y ligero)
model = YOLO('yolo11n.pt')
# 2. Entrenar el modelo
results = model.train(
data='dataset/data.yaml',
epochs=20, # Número de vueltas al dataset
imgsz=640, # Tamaño de la imagen
plots=True,
device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.6 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235 🚀 Python-3.13.5 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12044MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431257  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,425 parameters, 2,590,409 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3008.4±1373.5 MB/s, size: 41.2 KB)
# train: Scanning /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/dataset/train/labels.cache... 6455 images, 2516 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6455/6455 20.2Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 599.3±377.0 MB/s, size: 32.0 KB)
# val: Scanning /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/dataset/valid/labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576 525.8Kit/s 0.0s
# Plotting labels to /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/runs/detect/train2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      4.01G      1.294      3.174      1.454          6        640: 100% ━━━━━━━━━━━━ 404/404 7.6it/s 53.4s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s0.1s
#                    all        576        400      0.376      0.381      0.351      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      4.01G      1.377      2.218      1.477         13        640: 100% ━━━━━━━━━━━━ 404/404 9.4it/s 43.1s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.3it/s 1.7s.1s
#                    all        576        400      0.519      0.441      0.443       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      4.01G      1.383      1.875      1.475          3        640: 100% ━━━━━━━━━━━━ 404/404 9.5it/s 42.4s<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.5it/s 1.7s0.1s
#                    all        576        400      0.565      0.438      0.437      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      4.01G      1.344      1.717      1.453         11        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 42.2s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.5it/s 1.7s0.1s
#                    all        576        400      0.691      0.568      0.619      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      4.02G      1.253      1.504      1.388          5        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 42.1s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.7it/s 1.7s0.2s
#                    all        576        400      0.727      0.797      0.841       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      4.03G      1.212      1.394      1.354          5        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 41.9ss<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.7it/s 1.7s0.1s
#                    all        576        400      0.743      0.701      0.767      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      4.03G      1.161      1.287      1.326          3        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 41.9s<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.7it/s 1.7s0.1s
#                    all        576        400      0.787      0.768      0.856      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      4.03G      1.123      1.192      1.293          5        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 41.9s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.8it/s 1.7s0.1s
#                    all        576        400      0.792      0.806      0.853      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      4.04G      1.082      1.112      1.273          4        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 41.9s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.8it/s 1.7s0.2s
#                    all        576        400      0.821      0.859      0.893      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      4.04G      1.056      1.067      1.252          9        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 41.9ss<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.8it/s 1.7s0.2s
#                    all        576        400      0.889      0.823      0.905      0.669
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      4.04G     0.9397     0.7551      1.208          4        640: 100% ━━━━━━━━━━━━ 404/404 9.6it/s 42.0s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.8it/s 1.7s0.1s
#                    all        576        400       0.93       0.81      0.894      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      4.04G     0.9175      0.721      1.182          7        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.7s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.9it/s 1.7s0.2s
#                    all        576        400      0.926       0.86      0.927      0.702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      4.04G     0.8729     0.6557      1.158          6        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.6s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 11.0it/s 1.6s0.2s
#                    all        576        400      0.904       0.86      0.926      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      4.04G     0.8447     0.6022      1.132          4        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.6ss<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.9it/s 1.6s0.2s
#                    all        576        400      0.927      0.883       0.93      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      4.04G     0.8009     0.5572      1.112          4        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.6s<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 10.8it/s 1.7s0.1s
#                    all        576        400      0.916      0.907      0.939      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      4.04G     0.7727     0.5176      1.089          7        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.6s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 11.0it/s 1.6s0.2s
#                    all        576        400      0.918      0.917       0.93      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      4.04G     0.7363     0.4745      1.073          5        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.6ss<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 11.1it/s 1.6s0.2s
#                    all        576        400       0.93      0.915      0.948      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      4.04G      0.712     0.4521      1.048          4        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.6ss<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 11.1it/s 1.6s0.2s
#                    all        576        400      0.941      0.924      0.953      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      4.04G     0.6814     0.4222      1.028          2        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.7s<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 11.1it/s 1.6s0.1s
#                    all        576        400      0.934      0.925      0.956      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      4.04G     0.6589     0.4061      1.023          4        640: 100% ━━━━━━━━━━━━ 404/404 9.7it/s 41.7s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 11.1it/s 1.6s0.2s
#                    all        576        400       0.95      0.923      0.953      0.768
#
# 20 epochs completed in 0.247 hours.
# Optimizer stripped from /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.13.5 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12044MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.5it/s 1.9s<0.1s
#                    all        576        400      0.951      0.923      0.953      0.768
#                  Paper        132        139      0.967      0.921      0.961      0.771
#                   Rock        121        141      0.936      0.929       0.94      0.744
#               Scissors        116        120      0.948      0.919      0.958      0.789
# Speed: 0.3ms preprocess, 1.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_piedra_papel_tijeras/runs/detect/train2

# %%
from ultralytics import YOLO
import cv2
# Cargar el modelo entrenado
model = YOLO('runs/detect/train/weights/best.pt')
# Predecir en una imagen nueva
results = model.predict('', save=True)
# Ver los resultados
for r in results:
    print(r.boxes) # Muestra las cajas detectadas
# Out:
# 🔍 REALIZAR PREDICCIONES
# ================================================================================
#
# 📸 Imagen de prueba: /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_label_studio/dataset/images/val/cb7e8138-IMG_7255.jpeg
#    Existe: True
#
# ✅ Realizando predicción...
#
# image 1/1 /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_label_studio/dataset/images/val/cb7e8138-IMG_7255.jpeg: 640x480 1 Superthing, 66.1ms
# Speed: 12.7ms preprocess, 66.1ms inference, 100.5ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_label_studio/dataset/images/val/cb7e8138-IMG_7255.jpeg: 640x480 1 Superthing, 66.1ms
# Speed: 12.7ms preprocess, 66.1ms inference, 100.5ms postprocess per image at shape (1, 3, 640, 480)
# ✅ Predicción completada
#    Número de detecciones: 1
#
# 💾 Resultado guardado en: resultado_prediccion.jpg
#
# 📊 Visualizando resultado...
# ✅ Predicción completada
#    Número de detecciones: 1
#
# 💾 Resultado guardado en: resultado_prediccion.jpg
#
# 📊 Visualizando resultado...
