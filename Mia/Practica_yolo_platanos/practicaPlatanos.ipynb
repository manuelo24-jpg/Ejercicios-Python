# %%
# Celda 2: Importar librerías
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

print("✅ Librerías importadas correctamente")
# Out:
# ✅ Librerías importadas correctamente

# %%
# Celda 3: Verificar estructura del dataset
RUTA_DATASET = "Banana Ripeness Classification.v2-original-images_modifiedclasses.folder"

# Verificar que existe
if os.path.exists(RUTA_DATASET):
    print(f"✅ Dataset encontrado en: {RUTA_DATASET}")
    
    # Listar contenido
    print(f"\n📁 Contenido:")
    for item in os.listdir(RUTA_DATASET):
        print(f"  - {item}")
else:
    print(f"❌ ERROR: No se encontró el dataset en {RUTA_DATASET}")
    print("Verifica la ruta y que hayas descomprimido el archivo")
# Out:
# ✅ Dataset encontrado en: Banana Ripeness Classification.v2-original-images_modifiedclasses.folder
#
# 📁 Contenido:
#   - valid
#   - README.roboflow.txt
#   - train
#   - test
#   - README.dataset.txt

# %%
# Celda 4: Analizar distribución del dataset
def analizar_dataset(ruta_dataset):
    print("=" * 80)
    print("📊 ANÁLISIS DEL DATASET")
    print("=" * 80)
    
    splits = ['train', 'valid', 'test']
    resumen = {}
    
    for split in splits:
        ruta_split = os.path.join(ruta_dataset, split)
        
        if not os.path.exists(ruta_split):
            print(f"⚠️  Carpeta {split} no encontrada")
            continue
        
        print(f"\n📁 {split.upper()}:")
        clases = [d for d in os.listdir(ruta_split) if os.path.isdir(os.path.join(ruta_split, d))]
        
        total_split = 0
        for clase in clases:
            ruta_clase = os.path.join(ruta_split, clase)
            num_imgs = len([f for f in os.listdir(ruta_clase) 
                           if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
            print(f"  - {clase:20}: {num_imgs:4} imágenes")
            total_split += num_imgs
            
            if clase not in resumen:
                resumen[clase] = 0
            resumen[clase] += num_imgs
        
        print(f"  {'TOTAL':20}: {total_split:4} imágenes")
    
    print("\n" + "=" * 80)
    print("📈 RESUMEN TOTAL POR CLASE:")
    print("=" * 80)
    total_general = sum(resumen.values())
    for clase, cantidad in resumen.items():
        porcentaje = (cantidad / total_general * 100) if total_general > 0 else 0
        print(f"  {clase:20}: {cantidad:4} imágenes ({porcentaje:5.1f}%)")
    print(f"  {'TOTAL GENERAL':20}: {total_general:4} imágenes")
    
    return resumen

# Ejecutar análisis
analizar_dataset(RUTA_DATASET)
# Out:
# ================================================================================
# 📊 ANÁLISIS DEL DATASET
# ================================================================================
#
# 📁 TRAIN:
#   - rotten              : 1340 imágenes
#   - ripe                : 1174 imágenes
#   - unripe              :  634 imágenes
#   - overripe            :  783 imágenes
#   TOTAL               : 3931 imágenes
#
# 📁 VALID:
#   - rotten              :  388 imágenes
#   - ripe                :  339 imágenes
#   - unripe              :  167 imágenes
#   - overripe            :  229 imágenes
#   TOTAL               : 1123 imágenes
#
# 📁 TEST:
#   - rotten              :  185 imágenes
#   - ripe                :  154 imágenes
#   - unripe              :  110 imágenes
#   - overripe            :  113 imágenes
#   TOTAL               :  562 imágenes
#
# ================================================================================
# 📈 RESUMEN TOTAL POR CLASE:
# ================================================================================
#   rotten              : 1913 imágenes ( 34.1%)
#   ripe                : 1667 imágenes ( 29.7%)
#   unripe              :  911 imágenes ( 16.2%)
#   overripe            : 1125 imágenes ( 20.0%)
#   TOTAL GENERAL       : 5616 imágenes
# {'rotten': 1913, 'ripe': 1667, 'unripe': 911, 'overripe': 1125}

# %%
# Celda 5: Entrenar el modelo
print("🏋️  ENTRENAMIENTO DEL MODELO")
print("=" * 80)

# Configuración
MODELO = "yolo11n-seg.pt"  # Puedes cambiar a yolo11s-cls.pt o yolo11m-cls.pt
EPOCHS = 20
IMGSZ = 224
DEVICE = 'cpu'  # Cambiar a 'cuda' si tienes GPU

# Cargar modelo
print(f"\n📦 Cargando modelo: {MODELO}")
model = YOLO(MODELO)

# Entrenar
print(f"\n⏱️  Iniciando entrenamiento...")
print(f"  Dataset: {RUTA_DATASET}")
print(f"  Épocas: {EPOCHS}")
print(f"  Device: {DEVICE}")

results = model.train(
    data=RUTA_DATASET,
    epochs=EPOCHS,
    imgsz=IMGSZ,
    device=DEVICE,
    project='banana_training',
    name='ripeness_model',
    plots=True,
    verbose=True
)

print("\n✅ ¡Entrenamiento completado!")
print(f"📁 Resultados en: banana_training/ripeness_model/")
# Out:
# 🏋️  ENTRENAMIENTO DEL MODELO
# ================================================================================
#
# 📦 Cargando modelo: yolo11n-seg.pt
#
# ⏱️  Iniciando entrenamiento...
#   Dataset: Banana Ripeness Classification.v2-original-images_modifiedclasses.folder
#   Épocas: 20
#   Device: cpu
# New https://pypi.org/project/ultralytics/8.3.249 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235 🚀 Python-3.13.5 torch-2.9.1+cu128 CPU (11th Gen Intel Core i7-11700F @ 2.50GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Banana Ripeness Classification.v2-original-images_modifiedclasses.folder, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=ripeness_model2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=banana_training, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/ciabd12/Documentos/Ejercicios-Python/Mia/Practica_yolo_platanos/banana_training/ripeness_model2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:649, in BaseTrainer.get_dataset(self)
#     643 elif str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     644     "detect",
#     645     "segment",
#     646     "pose",
#     647     "obb",
#     648 }:
# --> 649     data = check_det_dataset(self.args.data)
#     650     if "yaml_file" in data:
#
# File ~/anaconda3/lib/python3.13/site-packages/ultralytics/data/utils.py:404, in check_det_dataset(dataset, autodownload)
#     403 extract_dir = ""
# --> 404 if zipfile.is_zipfile(file) or is_tarfile(file):
#     405     new_dir = safe_download(file, dir=DATASETS_DIR, unzip=True, delete=False)
#
# File ~/anaconda3/lib/python3.13/tarfile.py:2959, in is_tarfile(name)
#    2958 else:
# -> 2959     t = open(name)
#    2960 t.close()
#
# File ~/anaconda3/lib/python3.13/tarfile.py:1875, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1874 try:
# -> 1875     return func(name, "r", fileobj, **kwargs)
#    1876 except (ReadError, CompressionError) as e:
#
# File ~/anaconda3/lib/python3.13/tarfile.py:1943, in TarFile.gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1942 try:
# -> 1943     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1944 except OSError as e:
#
# File ~/anaconda3/lib/python3.13/gzip.py:203, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     202 if fileobj is None:
# --> 203     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     204 if filename is None:
#
# IsADirectoryError: [Errno 21] Is a directory: 'Banana Ripeness Classification.v2-original-images_modifiedclasses.folder'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 21
#      18 print(f"  Épocas: {EPOCHS}")
#      19 print(f"  Device: {DEVICE}")
# ---> 21 results = model.train(
#      22     data=RUTA_DATASET,
#      23     epochs=EPOCHS,
#      24     imgsz=IMGSZ,
#      25     device=DEVICE,
#      26     project='banana_training',
#      27     name='ripeness_model',
#      28     plots=True,
#      29     verbose=True
#      30 )
#      32 print("\n✅ ¡Entrenamiento completado!")
#      33 print(f"📁 Resultados en: banana_training/ripeness_model/")
#
# File ~/anaconda3/lib/python3.13/site-packages/ultralytics/engine/model.py:768, in Model.train(self, trainer, **kwargs)
#     765 if args.get("resume"):
#     766     args["resume"] = self.ckpt_path
# --> 768 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     769 if not args.get("resume"):  # manually set model only if not resuming
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~/anaconda3/lib/python3.13/site-packages/ultralytics/models/yolo/segment/train.py:40, in SegmentationTrainer.__init__(self, cfg, overrides, _callbacks)
#      38     overrides = {}
#      39 overrides["task"] = "segment"
# ---> 40 super().__init__(cfg, overrides, _callbacks)
#
# File ~/anaconda3/lib/python3.13/site-packages/ultralytics/models/yolo/detect/train.py:63, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      55 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks=None):
#      56     """Initialize a DetectionTrainer object for training YOLO object detection model training.
#      57
#      58     Args:
#    (...)
#      61         _callbacks (list, optional): List of callback functions to be executed during training.
#      62     """
# ---> 63     super().__init__(cfg, overrides, _callbacks)
#
# File ~/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:163, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     161 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     162 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 163     self.data = self.get_dataset()
#     165 self.ema = None
#     167 # Optimization utils init
#
# File ~/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:653, in BaseTrainer.get_dataset(self)
#     651             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     652 except Exception as e:
# --> 653     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     654 if self.args.single_cls:
#     655     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset 'Banana Ripeness Classification.v2-original-images_modifiedclasses.folder' error ❌ [Errno 21] Is a directory: 'Banana Ripeness Classification.v2-original-images_modifiedclasses.folder'

# %%
# Celda 6: Validar el modelo
print("🔍 VALIDACIÓN DEL MODELO")
print("=" * 80)

# Cargar mejor modelo
best_model = YOLO("banana_training/ripeness_model/weights/best.pt")

# Validar
metrics = best_model.val()

# Mostrar métricas
print(f"\n📊 RESULTADOS:")
print(f"  Top-1 Accuracy: {metrics.top1:.4f} ({metrics.top1*100:.2f}%)")
print(f"  Top-5 Accuracy: {metrics.top5:.4f} ({metrics.top5*100:.2f}%)")

# %%
# Celda 7: Visualizar matriz de confusión y curvas
print("📊 VISUALIZACIÓN DE RESULTADOS")
print("=" * 80)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Matriz de confusión
confusion_path = "banana_training/ripeness_model/confusion_matrix.png"
if os.path.exists(confusion_path):
    img = Image.open(confusion_path)
    axes[0].imshow(img)
    axes[0].axis('off')
    axes[0].set_title('Matriz de Confusión', fontsize=14, fontweight='bold')
else:
    axes[0].text(0.5, 0.5, 'No encontrada', ha='center', va='center')
    axes[0].axis('off')

# Curvas de entrenamiento
results_path = "banana_training/ripeness_model/results.png"
if os.path.exists(results_path):
    img = Image.open(results_path)
    axes[1].imshow(img)
    axes[1].axis('off')
    axes[1].set_title('Curvas de Entrenamiento', fontsize=14, fontweight='bold')
else:
    axes[1].text(0.5, 0.5, 'No encontrada', ha='center', va='center')
    axes[1].axis('off')

plt.tight_layout()
plt.savefig('resultados/analisis_completo.png', dpi=150, bbox_inches='tight')
plt.show()

print("💾 Gráfica guardada en: resultados/analisis_completo.png")

# %%
# Celda 8: Realizar predicciones en imágenes nuevas
print("🔮 PREDICCIONES EN IMÁGENES NUEVAS")
print("=" * 80)

def predecir_y_visualizar(ruta_imagen):
    """Predice y muestra resultado"""
    # Cargar modelo
    model = YOLO("banana_training/ripeness_model/weights/best.pt")
    
    # Predecir
    results = model(ruta_imagen)
    probs = results[0].probs
    
    # Obtener clase predicha
    clase_idx = probs.top1
    clase_nombre = model.names[clase_idx]
    confianza = probs.top1conf.item()
    
    # Cargar imagen
    img = Image.open(ruta_imagen)
    
    # Visualizar
    plt.figure(figsize=(10, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title(f'Predicción: {clase_nombre} ({confianza:.1%})', 
             fontsize=16, fontweight='bold', color='green' if confianza > 0.8 else 'orange')
    plt.tight_layout()
    
    # Guardar
    nombre_archivo = os.path.basename(ruta_imagen).split('.')[0]
    plt.savefig(f'resultados/prediccion_{nombre_archivo}.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    # Mostrar probabilidades
    print(f"\n📸 Imagen: {ruta_imagen}")
    print(f"🏆 Predicción: {clase_nombre}")
    print(f"📊 Confianza: {confianza:.2%}")
    print(f"\n📋 Todas las probabilidades:")
    for idx, prob in enumerate(probs.data):
        print(f"  {model.names[idx]:15}: {prob:.4f} ({prob*100:.1f}%)")
    print("-" * 80)
    
    return clase_nombre, confianza

# Probar con tus imágenes
imagenes_prueba = [
    "imagenes_prueba/banana_verde_1.jpg",
    "imagenes_prueba/banana_madura_1.jpg",
    "imagenes_prueba/banana_pasada_1.jpg",
]

resultados_pruebas = []
for img_path in imagenes_prueba:
    if os.path.exists(img_path):
        clase, conf = predecir_y_visualizar(img_path)
        resultados_pruebas.append({
            'imagen': os.path.basename(img_path),
            'prediccion': clase,
            'confianza': f"{conf:.2%}"
        })
    else:
        print(f"⚠️  No se encontró: {img_path}")

# Resumen
print("\n" + "=" * 80)
print("📋 RESUMEN DE PREDICCIONES")
print("=" * 80)
df_resultados = pd.DataFrame(resultados_pruebas)
print(df_resultados.to_string(index=False))

# %%
# Celda 9: Sección de conclusiones
print("""
╔════════════════════════════════════════════════════════════════════════════╗
║                            CONCLUSIONES                                    ║
╚════════════════════════════════════════════════════════════════════════════╝

📊 Métricas obtenidas:
  - Accuracy: XX.XX%
  - Clases: ripe, unripe, overripe

🎯 Análisis de la matriz de confusión:
  - La clase más confundida es: [completar]
  - Razón probable: [completar]

💡 Factores que afectan la precisión:
  1. Iluminación: [tu análisis]
  2. Fondo de la imagen: [tu análisis]
  3. Ángulo de captura: [tu análisis]
  4. Estado intermedio del plátano: [tu análisis]

🚀 Mejoras propuestas:
  1. Aumentar épocas a 50-100
  2. Usar modelo más grande (medium)
  3. Aplicar data augmentation
  4. Aumentar dataset con más variedad
  5. Probar con diferentes ángulos e iluminaciones

📚 Aprendizajes clave:
  - [Lo que aprendiste 1]
  - [Lo que aprendiste 2]
  - [Lo que aprendiste 3]
""")
