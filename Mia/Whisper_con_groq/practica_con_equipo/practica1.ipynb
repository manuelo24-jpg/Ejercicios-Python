# %%
# Instalamos la librería de Whisper desde el repositorio oficial
# !pip install git+https://github.com/openai/whisper.git
# Aseguramos que tenemos ffmpeg (necesario para procesar audio)
# !sudo apt update && sudo apt install ffmpeg -y
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-ko3gj0kz
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-ko3gj0kz
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from openai-whisper==20250625) (10.3.0)
# Requirement already satisfied: numba in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from openai-whisper==20250625) (0.61.0)
# Requirement already satisfied: numpy in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from openai-whisper==20250625) (2.1.3)
# Requirement already satisfied: tiktoken in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from openai-whisper==20250625) (0.12.0)
# Requirement already satisfied: torch in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from openai-whisper==20250625) (2.9.1)
# Requirement already satisfied: tqdm in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from openai-whisper==20250625) (4.67.1)
# Requirement already satisfied: triton>=2 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from openai-whisper==20250625) (3.5.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from numba->openai-whisper==20250625) (0.44.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from tiktoken->openai-whisper==20250625) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from tiktoken->openai-whisper==20250625) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20250625) (2025.10.5)
# Requirement already satisfied: filelock in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (4.12.2)
# Requirement already satisfied: setuptools in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from torch->openai-whisper==20250625) (1.13.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch->openai-whisper==20250625) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ciabd12/anaconda3/lib/python3.13/site-packages (from jinja2->torch->openai-whisper==20250625) (3.0.2)
# [sudo] contraseña para ciabd12:
# sudo: se requiere una contraseña
# ^C

# %%
import whisper
import os
# Elegimos el modelo (puedes cambiar "base" por "small" o "medium"
# según tu PC/GPU)
model = whisper.load_model("base")
print("Modelo cargado correctamente.")

# %%
audio_path = "audio_prueba.mp3" 
# Cambia esto por el nombre de tu archivo
if not os.path.exists(audio_path):
    print(f"Error: El archivo {audio_path} no existe. Por favor, súbelo.")
else:
    print(f"Archivo {audio_path} listo para procesar.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 audio_path = "audio_prueba.mp3"
#       2 # Cambia esto por el nombre de tu archivo
# ----> 3 if not os.path.exists(audio_path):
#       4     print(f"Error: El archivo {audio_path} no existe. Por favor, súbelo.")
#       5 else:
#
# NameError: name 'os' is not defined

# %%
# Transcribir el audio
result = model.transcribe(audio_path, verbose=False)
# El resultado es un diccionario que contiene el texto y otros metadatos
print("-" * 30)
print("TRANSCRIPCIÓN FINALIZADA")
print("-" * 30)
print(result["text"])

# %%
nombre_salida = "transcripcion_resultado.txt"
with open(nombre_salida, "w", encoding="utf-8") as f:
    f.write(result["text"])
    print(f"La transcripción se ha guardado en: {nombre_salida}")
