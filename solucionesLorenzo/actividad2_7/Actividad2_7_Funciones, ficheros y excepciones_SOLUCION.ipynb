# %% [markdown]
# # Actividad 2_7: Funciones, ficheros y excepciones.
#
# Descarga el archivo llamado nba.csv e introdúcelo en la misma carpeta en la que vas a solucionar este ejercicio.
#
# Este fichero CSV contiene información sobre los 30 equipos de la NBA en la temporada actual. La explicación de las columnas que contiene es la siguiente:
#
# - G -> Partidos jugados.
# - MP -> Minutos jugados.
# - FG -> Tidos de campo anotados.
# - FGA -> Tidos de campo intentados.
# - FG% -> Porcentaje de tiros de campo.
# - 3P -> Tiros de 3 puntos anotados.
# - 3PA -> Tiros de 3 puntos intentados.
# - 3P% -> Porcentaje de tiros de 3 puntos.
# - 2P ->  Tiros de 2 puntos anotados.
# - 2PA -> Tiros de 2 puntos intentados.
# - 2P% -> Porcentaje de tiros de 2 puntos.
# - FT -> Tiros libres anotados.
# - FTA -> Tiros libres intentados.
# - FT% -> Porcentaje de tiros libres.
# - ORB -> Rebotes ofensivos.
# - DRB -> Rebotes defensivos.
# - TRB -> Rebotes totales.
# - AST -> Asisencias (pases que acaban directamente en canasta).
# - STL -> Robos de balon.
# - BLK -> Tapones.
# - TOV -> Pérdidas.
# - PF -> Faltas personales.
# - PTS -> Puntos.

# %% [markdown]
# Debes escribir un programa que consiga los siguientes objetivos (introduce cuando sea necesario el tratamiento correspondiente de excepciones):
#
# 1. Debe importar los datos en un DataFrame.
# 2. Debe mostrar el menú que se muestra a continuación. Debes hacer cada una de las acciones del menú en una función separada. Para la función principal puedes usar un main o no, como lo consideres oportuno.
#
#     1 Añade Estado. (Esta función debe añadir una columna nueva con el Estado al que pertenece cada uno de los equipos de la NBA.)
#
#     2 Elimina columna. (Esta función debe pedir el nombre de una columna, comprobar que está bien y eliminar dicha columna).
#
#     3 Vuelve a cargar datos. (Esta función debe sobreescribir el DataFrame con los datos originales).
#
#     4 Ordena por columna. (Esta función debe pedir el nombre de una columna, comprobar que está bien y devovler los datos ordenados según dicha columna).
#
# 3. Crea una función que prediga en base a los datos que devuelva en base a los datos que tienes y a las reglas que consideres oportuno el porcentaje de probabilidad de ganar la NBA en la temporada actual que tienen cada uno de estos 30 equipos. Para hacer esto deberás investigar cada uno de los datos y decidir el impacto que tienen en el juego.

# %%
# Código
import pandas as pd
df_nba = pd.read_csv("nba.csv")

def anade_estados(df):
    estados = ["Utah","North Carolina","Arizona","New York","Wisconsin","Tennessee","California","Georgia","Minnesota","California","Texas","Illinois","California","Florida","Oregon","Texas","Indiana","Colorado","Washington DC","Massachussets","Pennsylvania","Ohio","Toronto","Louisianna","California","Texas","New York","Florida","Michigan","Oklahoma"]
    df["Estados"] = estados
    return df
    
def carga_datos(df):
    df = pd.read_csv("nba.csv")
    return df

def elimina_columna(df):
    print("Introduzca el nombre de la columna a eliminar.")
    columna = input("Nombre columna: ")
    if columna in df.columns:
        #del df[columna]
        #df = df.drop(columna,axis=1)
        #df.drop(columns=columna,inplace=True)
        df.drop(columna,inplace=True,axis=1)
    else:
        print("Se ha equivocado en el nombre de la columna.")
    return df
        
def ordena_columna(df):
    print("Introduzca el nombre de la columna con la que quiere ordenar los equipos.")
    columna = input("Nombre columna: ")
    if columna in df.columns:
        df = df.sort_values(by=[columna], ascending=False)
    else:
        print("Se ha equivocado en el nombre de la columna.")
    return df
        
    
    
while True:
    print("""Introduce una opción de las siguientes:
    1. Añade columna Estado.
    2. Elimina columna.
    3. Vuelve a cargar datos.
    4. Ordena por columna.
    5. Pinta dataframe.
    6. Salir.""")
    opcion = input("Opción: ")
    if opcion == "1":
        df_nba = anade_estados(df_nba)
    if opcion == "2":
        df_nba = elimina_columna(df_nba)        
    if opcion == "3":
        df_nba = carga_datos(df_nba)
    if opcion == "4":
        df_nba = ordena_columna(df_nba)
    if opcion == "5":
        print(df_nba.head())
    if opcion == "6":
        break
print("Cerrando programa...")
# Out:
# Introduce una opción de las siguientes:
#     1. Añade columna Estado.
#     2. Elimina columna.
#     3. Vuelve a cargar datos.
#     4. Ordena por columna.
#     5. Pinta dataframe.
#     6. Salir.
# Introduzca el nombre de la columna a eliminar.
# Introduce una opción de las siguientes:
#     1. Añade columna Estado.
#     2. Elimina columna.
#     3. Vuelve a cargar datos.
#     4. Ordena por columna.
#     5. Pinta dataframe.
#     6. Salir.
#    Rk   G     MP    FG   FGA    FG%    3P   3PA    3P%    2P  ...    FT%  \
# 0   1  47  240.0  40.7  86.3  0.472  14.7  40.6  0.362  26.1  ...  0.780
# 1   2  47  242.1  42.5  92.3  0.461  14.0  38.2  0.367  28.5  ...  0.736
# 2   3  45  240.6  42.5  89.4  0.476  11.5  31.7  0.363  31.0  ...  0.805
# 3   4  46  241.1  41.8  88.2  0.474  11.1  31.7  0.352  30.7  ...  0.827
# 4   5  49  241.0  40.4  89.2  0.454  14.3  39.5  0.362  26.2  ...  0.778
#
#     ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  10.3  36.3  46.6  22.2  6.9  4.9  14.1  18.9  114.2
# 1  10.6  33.9  44.4  27.1  8.8  5.1  13.1  19.3  114.1
# 2  10.0  36.0  46.0  26.4  8.8  4.2  13.5  19.5  112.5
# 3   9.8  35.5  45.3  25.6  7.0  5.5  14.2  20.1  112.2
# 4  10.4  36.8  47.2  23.0  7.7  4.4  13.8  17.9  112.0
#
# [5 rows x 24 columns]
# Introduce una opción de las siguientes:
#     1. Añade columna Estado.
#     2. Elimina columna.
#     3. Vuelve a cargar datos.
#     4. Ordena por columna.
#     5. Pinta dataframe.
#     6. Salir.
# Cerrando programa...

# %%
# Código
import pandas as pd
df_nba = pd.read_csv("nba.csv")

def prob_ganar(df):
    df["FG%"] = (df["FG%"] - df["FG%"].min()) / (df["FG%"].max() - df["FG%"].min())    
    df["3P%"] = (df["3P%"] - df["3P%"].min()) / (df["3P%"].max() - df["3P%"].min())    
    df["TRB"] = (df["TRB"] - df["TRB"].min()) / (df["TRB"].max() - df["TRB"].min())   
    df["STL"] = (df["STL"] - df["STL"].min()) / (df["STL"].max() - df["STL"].min()) 
    df["TOV"] = (df["TOV"] - df["TOV"].min()) / (df["TOV"].max() - df["TOV"].min()) 
    df["PROB"] = df["FG%"]*2+df["3P%"]*3+df["TRB"]+df["STL"]-df["TOV"]
    df["PROB"] = df["PROB"]**5
    df["PROB"] = df['PROB']*100/df['PROB'].sum()
    df = df.sort_values(by=["PROB"], ascending=False)
    return df[['Team','PROB']]
        
print(prob_ganar(df_nba))
# Out:
#                       Team       PROB
# 2             Phoenix Suns  14.884479
# 11           Chicago Bulls  11.837604
# 7            Atlanta Hawks   9.129335
# 1        Charlotte Hornets   8.970496
# 0                Utah Jazz   7.454467
# 13              Miami Heat   6.565700
# 4          Milwaukee Bucks   5.735153
# 12   Golden State Warriors   4.905576
# 10       San Antonio Spurs   4.547367
# 5        Memphis Grizzlies   4.480484
# 3            Brooklyn Nets   3.819374
# 20      Philadelphia 76ers   2.967112
# 6       Los Angeles Lakers   2.473336
# 21     Cleveland Cavaliers   1.820679
# 14  Portland Trail Blazers   1.706749
# 17          Denver Nuggets   1.585046
# 24    Los Angeles Clippers   1.267566
# 9         Sacramento Kings   1.190076
# 26         New York Knicks   1.151225
# 22         Toronto Raptors   1.078083
# 19          Boston Celtics   0.610479
# 8   Minnesota Timberwolves   0.595487
# 18      Washington Wizards   0.279234
# 23    New Orleans Pelicans   0.277751
# 25        Dallas Mavericks   0.261936
# 16          Indiana Pacers   0.217617
# 15         Houston Rockets   0.184899
# 27           Orlando Magic   0.002256
# 29   Oklahoma City Thunder   0.000403
# 28         Detroit Pistons   0.000029
