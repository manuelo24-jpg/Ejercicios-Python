# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

df_adults = pd.read_csv('adult.csv')

#Copia del dataframe

wished_columns = [
    'age', 'workclass', 'education', 'occupation', 'hours.per.week', 'income', 
    'race', 'sex','capital.gain', 'native.country', 'capital.loss'
]

df_model = df_adults[wished_columns].copy()

#Limpieza de datos

print(df_model.info())
print(df_model.shape)
df_model.replace('?', np.nan, inplace=True)
df_model.dropna(inplace=True)
print(df_model.shape)

X = df_model.drop('hours.per.week', axis=1)
y = df_model['hours.per.week']
df_model.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   occupation      32561 non-null  object
#  4   hours.per.week  32561 non-null  int64
#  5   income          32561 non-null  object
#  6   race            32561 non-null  object
#  7   sex             32561 non-null  object
#  8   capital.gain    32561 non-null  int64
#  9   native.country  32561 non-null  object
#  10  capital.loss    32561 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 2.7+ MB
# None
# (32561, 11)
#    age workclass     education         occupation  hours.per.week income  \
# 1   82   Private       HS-grad    Exec-managerial              18  <=50K
# 3   54   Private       7th-8th  Machine-op-inspct              40  <=50K
# 4   41   Private  Some-college     Prof-specialty              40  <=50K
# 5   34   Private       HS-grad      Other-service              45  <=50K
# 6   38   Private          10th       Adm-clerical              40  <=50K
#
#     race     sex  capital.gain native.country  capital.loss
# 1  White  Female             0  United-States          4356
# 3  White  Female             0  United-States          3900
# 4  White  Female             0  United-States          3900
# 5  White  Female             0  United-States          3770
# 6  White    Male             0  United-States          3770
